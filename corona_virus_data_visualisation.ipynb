# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
corona=pd.read_csv(r'C:\Users\user\Desktop\corona.csv')

# %%
corona=corona.dropna()

# %%
corona1_xaxis=corona.iloc[:6,2]
corona2_xaxis=corona.iloc[6:12,2]
corona3_xaxis=corona.iloc[12:18,2]
corona4_xaxis=corona.iloc[18:24,2]
corona5_xaxis=corona.iloc[24:30,2]
corona6_xaxis=corona.iloc[30:36,2]

# %%
corona1_yaxis=corona.iloc[:6,-3]
corona2_yaxis=corona.iloc[6:12,-3]
corona3_yaxis=corona.iloc[12:18,-3]
corona4_yaxis=corona.iloc[18:24,-3]
corona5_yaxis=corona.iloc[24:30,-3]
corona6_yaxis=corona.iloc[30:36,-3]

# %%
plt.bar(corona1_xaxis,corona1_yaxis,label='Corona_Virus Affects')
plt.legend()

# %%
plt.bar(corona2_xaxis,corona2_yaxis)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(corona3_xaxis,corona3_yaxis)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(corona4_xaxis,corona4_yaxis)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(corona5_xaxis,corona5_yaxis)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(corona6_xaxis,corona6_yaxis)
# Out:
# <BarContainer object of 6 artists>
